# %% [markdown]
# <a href="https://colab.research.google.com/github/caiocfpeixoto/CNN/blob/main/VGG19_%26_Random_Forest_results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vetor_resultados = [[0.7659110723626853, 0.8985042735042735, 0.6554949337490257, 0.5418160313321754],
                    [0.7907585004359198, 0.8824786324786325, 0.6906354515050167, 0.5847800969570451],
                    [0.7720139494333043, 0.8814102564102564, 0.6669361358124495, 0.5505159227603198],
                    [0.7606800348735833, 0.8814102564102564, 0.6532066508313539, 0.530102195010018],
                    [0.7785527462946817, 0.8995726495726496, 0.6703821656050956, 0.5647149875094127],
                    [0.7737576285963382, 0.8995726495726496, 0.664561957379637, 0.5560592693572888],
                    [0.7772449869224063, 0.8899572649572649, 0.6712328767123288, 0.5611066889414225],
                    [0.7794245858761988, 0.8846153846153846, 0.6753670473083198, 0.564368697824328],
                    [0.7676547515257193, 0.8910256410256411, 0.6592885375494071, 0.5439404643168593],
                    [0.7781168265039233, 0.875, 0.6763005780346821, 0.560742389849471]]

# %%
df = pd.DataFrame(vetor_resultados, columns=['Accuracy', 'Recall', 'Precision', 'Kappa'])

# Crie uma figura e eixos para o gráfico
fig, ax = plt.subplots(figsize=(10, 6))

# Crie um boxplot para as colunas do DataFrame
sns.boxplot(data=df[['Accuracy', 'Recall', 'Precision', 'Kappa']], ax=ax, palette='Set1', width=0.5)

# Crie um stripplot para as mesmas colunas (usando um eixo diferente)
sns.stripplot(data=df[['Accuracy', 'Recall', 'Precision', 'Kappa']], ax=ax, jitter=True, color='black', alpha=0.5)

# Rotule o eixo y
ax.set_ylabel('Valor')

# Defina o título do gráfico
ax.set_title('Boxplot e Stripplot das Métricas')

# Exiba o gráfico
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:black'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %%
df['seed'] = [12, 22, 32, 42, 52, 62, 72, 82, 92, 102]
display(df)
# Out:
#    Accuracy    Recall  Precision     Kappa  seed
# 0  0.765911  0.898504   0.655495  0.541816    12
# 1  0.790759  0.882479   0.690635  0.584780    22
# 2  0.772014  0.881410   0.666936  0.550516    32
# 3  0.760680  0.881410   0.653207  0.530102    42
# 4  0.778553  0.899573   0.670382  0.564715    52
# 5  0.773758  0.899573   0.664562  0.556059    62
# 6  0.777245  0.889957   0.671233  0.561107    72
# 7  0.779425  0.884615   0.675367  0.564369    82
# 8  0.767655  0.891026   0.659289  0.543940    92
# 9  0.778117  0.875000   0.676301  0.560742   102

# %%
# Calcular as médias das colunas
media = [sum(col) / len(col) for col in zip(*vetor_resultados)]

# Criar um DataFrame com as métricas como índices e uma única coluna 'média'
df_media = pd.DataFrame(media, index=['Accuracy', 'Recall', 'Precision', 'Kappa'], columns=['média'])

display(df_media)
# Out:
#               média
# Accuracy   0.774412
# Recall     0.888355
# Precision  0.668341
# Kappa      0.555815

# %%
# Para criar o histograma da coluna 'Accuracy' com o Seaborn:
sns.histplot(df['Accuracy'], kde=True, color='blue')

# Personalize o gráfico com rótulos e título
plt.xlabel('Accuracy')
plt.ylabel('Densidade')
plt.title('Histograma da Accuracy')

# Exibir o gráfico
plt.show()
